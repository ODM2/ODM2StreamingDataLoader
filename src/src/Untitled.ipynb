# %%
import pandas as pd

# %%
df = pd.read_csv("/home/denver/Documents/ODM2StreamingDataLoader/tests/test_handlers/test_csvHandler/csvFiles/Treeline_HrlySummary_2014_giga.csv", header=19)

# %%
df.set_index(['DateTime'], inplace=True)
df
# Out:
#                  Precipitation-mm  AirTemperature-C  SolarRadiation-Watts/m2  \
# DateTime
# 1/1/2014 0:00                 0.0              -0.4                     0.00
# 1/1/2014 1:00                 0.0              -0.4                     0.00
# 1/1/2014 2:00                 0.0              -1.0                     0.00
# 1/1/2014 3:00                 0.0              -0.7                     0.00
# 1/1/2014 4:00                 0.0              -0.6                     0.00
# 1/1/2014 5:00                 0.0              -1.2                     0.00
# 1/1/2014 6:00                 0.0              -0.4                     0.00
# 1/1/2014 7:00                 0.0              -0.8                     0.00
# 1/1/2014 8:00                 0.0              -0.9                     0.00
# 1/1/2014 9:00                 0.0              -0.8                    47.77
# 1/1/2014 10:00                0.0               0.4                   244.60
# ...
